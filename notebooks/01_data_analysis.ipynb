# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/internships.csv')

df.shape
df.columns.tolist()
df.head()
# Out:
#   internship_id            Date Time               profile  \
# 0  2025WSHP0080  2025-09-21 15:24:28  Full Stack Developer
# 1  2025WSHP0165  2025-09-21 15:58:52          UI/UX Design
# 2  2025WSHP0242  2025-09-21 16:13:20    Frontend Developer
# 3  2025WSHP0016  2025-09-27 23:11:11    Frontend Developer
# 4  2025WSHP0513  2025-09-21 16:02:53   Flutter Development
#
#                                     company        Location   Start Date  \
# 0                       Cogent Web Services  Work from home  Immediately
# 1                                Eduminatti  Work from home  Immediately
# 2                        LSOYS Games & Apps  Work from home  Immediately
# 3             InstaWeb Labs Private Limited          Mumbai  Immediately
# 4  Pragament Tech Solutions Private Limited  Work from home  Immediately
#
#                     Stipend  Duration Apply by Date  \
# 0           ₹ 10,000 /month  3 Months    11 Oct' 25
# 1   ₹ 5,000 - 10,000 /month  2 Months    18 Oct' 25
# ...

# %%
df.tail()
# Out:
#     internship_id            Date Time                        profile  \
# 195  2025WSHP0603  2025-09-27 22:39:04  Media & Public Relations (PR)
# 196  2025WSHP0202  2025-09-27 21:47:17                Market Research
# 197  2025WSHP1518  2025-09-27 20:54:31              Business Research
# 198  2025WSHP0769  2025-09-27 21:11:47            Research & Insights
# 199  2025WSHP3928  2025-09-27 21:06:39                 Legal Research
#
#                                    company       Location   Start Date  \
# 195  Veritas Reputation PR Private Limited         Mumbai  Immediately
# 196    Suspol Technologies Private Limited  Greater Noida  Immediately
# 197          SCDND ESTATES PRIVATE LIMITED  Greater Noida  Immediately
# 198                                 Caarya        Chennai  Immediately
# 199                   Janus Law Associates          Delhi  Immediately
#
#                      Stipend  Duration Apply by Date  \
# 195  ₹ 5,000 - 10,000 /month  2 Months    22 Oct' 25
# ...

# %%
df.nunique()
# Out:
# internship_id       200
# Date Time           123
# profile              61
# company              73
# Location             13
# Start Date            3
# Stipend              46
# Duration              6
# Apply by Date       112
# Skills              162
# Eligibility           4
# Perks                12
# Description         200
# deadline_is_demo      2
# domain                7
# work_mode             3
# internship_type       3
# dtype: int64

# %%
df['company'].duplicated().sum()
# Out:
# np.int64(127)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   internship_id     200 non-null    str
#  1   Date Time         200 non-null    str
#  2   profile           200 non-null    str
#  3   company           200 non-null    str
#  4   Location          200 non-null    str
#  5   Start Date        200 non-null    str
#  6   Stipend           200 non-null    str
#  7   Duration          200 non-null    str
#  8   Apply by Date     200 non-null    str
#  9   Skills            200 non-null    str
#  10  Eligibility       200 non-null    str
#  11  Perks             200 non-null    str
#  12  Description       200 non-null    str
#  13  deadline_is_demo  170 non-null    object
#  14  domain            170 non-null    str
#  15  work_mode         200 non-null    str
#  16  internship_type   200 non-null    str
# dtypes: object(1), str(16)
# ...

# %%
df.isnull().sum()
# Out:
# internship_id        0
# Date Time            0
# profile              0
# company              0
# Location             0
# Start Date           0
# Stipend              0
# Duration             0
# Apply by Date        0
# Skills               0
# Eligibility          0
# Perks                0
# Description          0
# deadline_is_demo    30
# domain              30
# work_mode            0
# internship_type      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['internship_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
print("ELIGIBILITY VALUES:")
print(df["eligibility"].unique())

print("\nLOCATION VALUES:")
print(df["location"].unique())

print("\nDURATION VALUES:")
print(df["duration"].unique())

print("\nSTIPEND SAMPLE:")
print(df["stipend"].head(20).to_string(index=False))
# Out:
# ELIGIBILITY VALUES:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\LENOVO\Desktop\AI ML\sklearn-env\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
print("SKILLS SAMPLE:")
print(df["skills"].head(20).to_string(index=False))

print("\nSKILLS MISSING:")
print(df["skills"].isna().sum())

print("\nEMPTY SKILLS:")
print((df["skills"].str.strip() == "").sum())
# Out:
# SKILLS SAMPLE:
#            B2B Sales, Field Sales, Lead Generation
# English Proficiency (Spoken), English Proficien...
# English Proficiency (Spoken), English Proficien...
# Content Marketing, Digital Marketing, Sales, So...
#              Adobe Photoshop, Canva, Video Editing
# Content Management, Digital Marketing, Search E...
# Social Media Marketing, Video Editing, Video Ma...
# Digital Marketing, English Proficiency (Spoken)...
#                                      Not Available
# Effective Communication, English Proficiency (S...
# Blogging, Creative Writing, English Proficiency...
# Analytical Thinking, Data Extraction, MS-Excel,...
#                               MERN, Node.js, React
#                   Search Engine Optimization (SEO)
# English Proficiency (Spoken), English Proficien...
# Effective Communication, English Proficiency (S...
# Effective Communication, Interpersonal skills, ...
# Legal Drafting, Legal Research, Legal Writing, ...
# ...

# %%
print("\nDESCRIPTION SAMPLE:")
print(df["description"].head(5).to_string(index=False))
# Out:
# DESCRIPTION SAMPLE:
# This Business Development (Sales) internship is...
# This Digital Marketing internship is focused on...
# This Human Resources (HR) internship is focused...
# This Content and Social Media Marketing interns...
# This Graphic Design internship is focused on de...

# %%
''' Phase 1 — Final Conclusion

Humne dataset me ye verify kar liya:

200 internships
13 columns
No actual null values found
eligibility → 3 categories
location → 26 unique values
role → 200 unique values
skills → 193 unique combinations
description → 200 unique descriptions
stipend → mixed text format
duration → mixed/dirty values
location → Remote / Work from home ko later standardize karna hoga
duration → 1 week ago, 3 weeks ago jaise suspicious values identify hue
stipend → ranges, single values, Unpaid, Not Available identify hue'''

# %%
#Phase 2 — Data Preprocessing
